# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
sorted_data = ds.sort_values(by='price', ascending=False)

most_expensive_house = sorted_data.iloc[0]

print("The most expensive house with address", most_expensive_house['address'], "with a price of", most_expensive_house['price'])
# Out:
# The most expensive house with address El Escorial with a price of 8500000

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# Sort the dataset by price in ascending order
sorted_data = ds.sort_values(by='price')

# Get the cheapest house
cheapest_house = sorted_data.iloc[0]

# Print the result
print(f"The house with address {cheapest_house['address']} is the cheapest and its price is {cheapest_house['price']} USD")
# Out:
# The house with address Plaza Canto Redondo, 5, Getafe is the cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# Sort the dataset by surface area in descending order to find the biggest house
sorted_by_surface_desc = ds.sort_values(by='surface', ascending=False)
biggest_house = sorted_by_surface_desc.iloc[0]

# Sort the dataset by surface area in ascending order to find the smallest house
sorted_by_surface_asc = ds.sort_values(by='surface')
smallest_house = sorted_by_surface_asc.iloc[0]

# Print the results
print(f"The bigger house is located on {biggest_house['address']} and its surface is {biggest_house['surface']} meters")
print(f"The smaller house is located on {smallest_house['address']} and its surface is {smallest_house['surface']} meters")
# Out:
# The bigger house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smaller house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
unique_populations = ds['level5'].unique()
populations = ', '.join(unique_populations)
print(populations)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# Check if there are any missing values in the dataset
contains_nas = ds.isnull().values.any()

# Get rows and columns that contain NAs
rows_with_nas = ds[ds.isnull().any(axis=1)]
cols_with_nas = ds.columns[ds.isnull().any()].tolist()


print(f"Contains NAs: {contains_nas}")

# Print the rows that contain NAs
print("Rows with NAs:")
print(rows_with_nas)

# Print the columns that contain NAs
print("Columns with NAs:")
print(cols_with_nas)
# Out:
# Contains NAs: True
# Rows with NAs:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
original_shape = ds.shape

# Delete rows with NAs
ds_cleaned = ds.dropna()

# New dimensions of the DataFrame after deletion
new_shape = ds_cleaned.shape

# Print the comparison
print(f"Original dimensions: {original_shape}")
print(f"New dimensions after deleting NAs: {new_shape}")
# Out:
# Original dimensions: (15335, 37)
# New dimensions after deleting NAs: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# Filter the DataFrame for the population "Arroyomolinos (Madrid)"
arroyomolinos_data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]

# Calculate the mean price
mean_price_arroyomolinos = arroyomolinos_data['price'].mean()

# Print the result
print(f"The mean price of houses in Arroyomolinos (Madrid) is {mean_price_arroyomolinos} USD")
# Out:
# The mean price of houses in Arroyomolinos (Madrid) is 294541.59854014596 USD

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the DataFrame for the population "Arroyomolinos (Madrid)"
arroyomolinos_data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]

# Plot the histogram of prices
plt.figure(figsize=(10, 6))
plt.hist(arroyomolinos_data['price'], bins=10, edgecolor='black')
plt.title('Histogram of House Prices in Arroyomolinos (Madrid)')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # We can observe that the price ranges concentrate between around 175k and 400k. Meaning a significant amount of homes are listed at those ranges

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# Filter the DataFrame for the populations "Valdemorillo" and "Galapagar"
valdemorillo_data = ds[ds['level5'] == "Valdemorillo"]
galapagar_data = ds[ds['level5'] == "Galapagar"]

# Calculate the mean prices
mean_price_valdemorillo = valdemorillo_data['price'].mean()
mean_price_galapagar = galapagar_data['price'].mean()

# Print the average prices
print(f"The average price of houses in Valdemorillo is {mean_price_valdemorillo} USD")
print(f"The average price of houses in Galapagar is {mean_price_galapagar} USD")

if mean_price_valdemorillo == mean_price_galapagar:
    conclusion = "The average prices of houses in Valdemorillo and Galapagar are the same."
else:
    conclusion = "The average prices of houses in Valdemorillo and Galapagar are different"

print(conclusion)
# Out:
# The average price of houses in Valdemorillo is 363860.2931034483 USD
# The average price of houses in Galapagar is 360063.20238095237 USD
# The average prices of houses in Valdemorillo and Galapagar are different

# %%
# TODO

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

ds['pps'] = ds['price'] / ds['surface']

# Filter the DataFrame for the populations "Valdemorillo" and "Galapagar"
valdemorillo_data = ds[ds['level5'] == "Valdemorillo"]
galapagar_data = ds[ds['level5'] == "Galapagar"]

# Calculate the mean price per square meter
mean_pps_valdemorillo = valdemorillo_data['pps'].mean()
mean_pps_galapagar = galapagar_data['pps'].mean()

# Print the average prices per square meter
print(f"The average price per square meter of houses in Valdemorillo is {mean_pps_valdemorillo:.2f} USD/m²")
print(f"The average price per square meter of houses in Galapagar is {mean_pps_galapagar:.2f} USD/m²")

# Conclusion
if mean_pps_valdemorillo == mean_pps_galapagar:
    conclusion = "The average prices per square meter of houses in Valdemorillo and Galapagar are the same."
else:
    conclusion = "The average prices per square meter of houses in Valdemorillo and Galapagar are different."

print(conclusion)
# Out:
# The average price per square meter of houses in Valdemorillo is 1317.95 USD/m²
# The average price per square meter of houses in Galapagar is 1606.32 USD/m²
# The average prices per square meter of houses in Valdemorillo and Galapagar are different.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(ds['surface'], ds['price'], alpha=0.5)
plt.title('Scatter Plot of Surface Area vs. Price of Houses')
plt.xlabel('Surface Area (m²)')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# The majority of the data points are clustered on the left side of the plot, indicating that most houses have a smaller surface area. These houses have a wide range of prices, from lower to higher.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# Count unique values in the 'realEstate_name' column
unique_agencies_by_name = ds['realEstate_name'].nunique()

# Count unique values in the 'phone_realEstate' column, assuming this is the correct name
unique_agencies_by_phone = ds['phone_realEstate'].nunique()

# Print the obtained values
print(f"Number of unique real estate agencies by name: {unique_agencies_by_name}")
print(f"Number of unique real estate agencies by phone number: {unique_agencies_by_phone}")
# Out:
# Number of unique real estate agencies by name: 1821
# Number of unique real estate agencies by phone number: 1807

# %% [markdown]
# This suggests that while there are a total of 1821 different agents, some share the same number, indicating that there are a total of 1807 different agencies

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# Group the dataset by the 'level5' column and count the number of houses in each population
population_counts = ds['level5'].value_counts()

# Get the population with the most houses
most_houses_population = population_counts.idxmax()
most_houses_count = population_counts.max()
print(f"The population with the most houses is {most_houses_population} with {most_houses_count} houses.")
# Out:
# The population with the most houses is  Madrid Capital with 6643 houses.

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# List of populations for the "south belt" of Madrid
south_belt_populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a subset of the DataFrame that contains only the specified populations
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]

print(south_belt_df)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of populations for the "south belt" of Madrid
south_belt_populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a subset of the DataFrame that contains only the specified populations
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]

# Calculate the median prices for each population
median_prices = south_belt_df.groupby('level5')['price'].median()

# Create a bar plot of the median prices
plt.figure(figsize=(10, 6))
median_prices.plot(kind='bar', color='skyblue')
plt.title('Median House Prices in the South Belt of Madrid')
plt.xlabel('Population')
plt.ylabel('Median Price (USD)')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# Getafe has the highest median house price among the listed populations, with a median price significantly higher than the others.
# Fuenlabrada has the lowest median house price among the listed populations.
# Alcorcón and Leganés have similar median house prices, which are in between the median prices of Getafe and Fuenlabrada.
# The higher median price in Getafe might be due to higher demand, better facilities, or a more affluent population.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# Calculate the sample mean and variance 
variables = ['price', 'rooms', 'surface', 'bathrooms']
means = south_belt_df[variables].mean()
variances = south_belt_df[variables].var()

# Print the sample means
print("Sample Means:")
for var in variables:
    print(f"The sample mean of {var} is {means[var]:.2f}")

# Print the sample variances
print("\nSample Variances:")
for var in variables:
    print(f"The sample variance of {var} is {variances[var]:.2f}")
# Out:
# Sample Means:
# The sample mean of price is 223094.48
# The sample mean of rooms is 3.02
# The sample mean of surface is 111.75
# The sample mean of bathrooms is 1.63
#
# Sample Variances:
# The sample variance of price is 14921367508.05
# The sample variance of rooms is 0.72
# The sample variance of surface is 4263.05
# The sample variance of bathrooms is 0.57

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# Group by population and find the house with the maximum price in each group
most_expensive_houses = south_belt_df.loc[south_belt_df.groupby('level5')['price'].idxmax()]
most_expensive_houses_info = most_expensive_houses[['level5', 'address', 'price']]

# Print the DataFrame with the most expensive house
print(most_expensive_houses_info)
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# `#### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib`

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Normalize the prices within each population using Min-Max normalization
south_belt_df['normalized_price'] = south_belt_df.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

# Plot histograms of normalized prices for each population
populations = south_belt_populations
plt.figure(figsize=(12, 8))

for population in populations:
    subset = south_belt_df[south_belt_df['level5'] == population]
    plt.hist(subset['normalized_price'], bins=20, alpha=0.5, label=population)

plt.title('Normalized Price Histograms for South Belt Populations')
plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_738/1673131067.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_belt_df['normalized_price'] = south_belt_df.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# Create a new column for price per square meter (pps)
south_belt_df['pps'] = south_belt_df['price'] / south_belt_df['surface']

# Filter the DataFrame for Getafe and Alcorcón
getafe_df = south_belt_df[south_belt_df['level5'] == "Getafe"]
alcorcon_df = south_belt_df[south_belt_df['level5'] == "Alcorcón"]

# Calculate the mean price per square meter for each population
mean_pps_getafe = getafe_df['pps'].mean()
mean_pps_alcorcon = alcorcon_df['pps'].mean()

# Print the results
print(f"The mean price per square meter in Getafe is {mean_pps_getafe:.2f} USD/m²")
print(f"The mean price per square meter in Alcorcón is {mean_pps_alcorcon:.2f} USD/m²")

getafe_pps = getafe_df['pps'].describe()
alcorcon_pps = alcorcon_df['pps'].describe()

print("\nGetafe price per square meter statistics:")
print(getafe_pps)

print("\nAlcorcón price per square meter statistics:")
print(alcorcon_pps)
# Out:
# The mean price per square meter in Getafe is 2066.31 USD/m²
# The mean price per square meter in Alcorcón is 2239.30 USD/m²
#
# Getafe price per square meter statistics:
# count     241.000000
# mean     2066.314949
# std       741.872702
# min         0.000000
# 25%      1684.285714
# 50%      1973.333333
# 75%      2628.787879
# max      3827.160494
# Name: pps, dtype: float64
#
# Alcorcón price per square meter statistics:
# count     173.000000
# mean     2239.302480
# std       539.951527
# min       604.761905
# 25%      1904.081633
# 50%      2207.792208
# 75%      2472.727273
# max      3698.159509
# Name: pps, dtype: float64
# /tmp/ipykernel_738/3499447480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
import matplotlib.pyplot as plt

# Create a new column for price per square meter (pps)
south_belt_df['pps'] = south_belt_df['price'] / south_belt_df['surface']

# List of populations for the "south belt" of Madrid
populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 10), sharex=True, sharey=True)
fig.suptitle('Scatter Plots of Price per Square Meter (pps) for South Belt Populations')

# Scatter plot for each population
for ax, population in zip(axs.flatten(), populations):
    subset = south_belt_df[south_belt_df['level5'] == population]
    ax.scatter(subset['surface'], subset['pps'], alpha=0.5)
    ax.set_title(population)
    ax.set_xlabel('Surface Area (m²)')
    ax.set_ylabel('Price per Square Meter (USD/m²)')
    ax.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()
# Out:
# /tmp/ipykernel_738/3217730822.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_belt_df['pps'] = south_belt_df['price'] / south_belt_df['surface']

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
# Out:
#      latitude  longitude
# 1         NaN        NaN
# 3         NaN        NaN
# 85        NaN        NaN
# 94        NaN        NaN
# 109       NaN        NaN
# latitude     float64
# longitude    float64
# dtype: object
#        latitude  longitude
# count      11.0       11.0
# mean        0.0        0.0
# std         0.0        0.0
# min         0.0        0.0
# 25%         0.0        0.0
# 50%         0.0        0.0
# 75%         0.0        0.0
# max         0.0        0.0
# latitude     896
# longitude    896
# dtype: int64
# Latitude range: 0.0 to 0.0
# Longitude range: 0.0 to 0.0
# /tmp/ipykernel_738/2520382023.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
